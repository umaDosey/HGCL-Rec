# %%
import matplotlib.pyplot as plt

# Extracted log data
epochs = [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99]
recall_values = [0.0891, 0.1113, 0.1179, 0.1206, 0.1224, 0.1219, 0.1224, 0.1227, 0.1228, 0.1228, 0.1223, 0.1223, 0.1216, 0.1220, 0.1219, 0.1224, 0.1227, 0.1228, 0.1224, 0.1216, 0.1208, 0.1206, 0.1204, 0.1204, 0.1199, 0.1201, 0.1201, 0.1197, 0.1195, 0.1196, 0.1193, 0.1195, 0.1186, 0.1187]

ndcg_values = [0.0687, 0.0853, 0.0907, 0.0931, 0.0946, 0.0950, 0.0958, 0.0958, 0.0958, 0.0956, 0.0957, 0.0955, 0.0955, 0.0951, 0.0944, 0.0943, 0.0945, 0.0950, 0.0955, 0.0951, 0.0939, 0.0939, 0.0939, 0.0937, 0.0939, 0.0936, 0.0933, 0.0933, 0.0929, 0.0929, 0.0928, 0.0928, 0.0926, 0.0926]


test_recall = [0.0628, 0.0963, 0.1127, 0.1205, 0.1251, 0.1253, 0.1272, 0.1267, 0.1257, 0.1264, 
               0.1270, 0.1268, 0.1256, 0.1263, 0.1270, 0.1261, 0.1268,0.1261, 0.1268, 0.1275, 0.1270, 0.1270,
               0.1270, 0.1270, 0.1270, 0.1270, 0.1273, 0.1289, 0.1263, 0.1270, 0.1280, 0.1273,
               0.1281, 0.1270]

test_ndcg = [0.0480, 0.0750, 0.0869, 0.0938, 0.0970, 0.0975, 0.0981, 0.0984, 0.0984, 0.0986,
             0.0986, 0.0986, 0.0986, 0.0985, 0.0985, 0.0982, 0.0983, 0.0984, 0.0984, 0.0982,
             0.0989, 0.0984, 0.0986, 0.0986, 0.0986, 0.0987, 0.0990, 0.0987, 0.0982, 0.0988,
             0.0992, 0.0986, 0.0987, 0.0987, 0.0987, 0.0987]

recall_values2 = [0.1072, 0.1210, 0.1194, 0.1150, 0.1129, 0.1158, 0.1192, 0.1206, 0.1225, 0.1245, 0.1260, 0.1272, 0.1286, 0.1294, 0.1296, 0.1305, 0.1307, 0.1315, 0.1316, 0.1312, 0.1317, 0.1314, 0.1316, 0.1319, 0.1318, 0.1312, 0.1314, 0.1310, 0.1312, 0.1310, 0.1313, 0.1314, 0.1310, 0.1311]

ndcg_values2 = [0.0834, 0.0933, 0.0917, 0.0884, 0.0868, 0.0887, 0.0915, 0.0929, 0.0945, 0.0962, 0.0974, 0.0982, 0.0993, 0.0998, 0.1001, 0.1008, 0.1010, 0.1013, 0.1016, 0.1012, 0.1016, 0.1016, 0.1017, 0.1017, 0.1016, 0.1014, 0.1013, 0.1013, 0.1012, 0.1011, 0.1011, 0.1011, 0.1010, 0.1010]

# Plotting
plt.figure(figsize=(10, 6))
# plt.plot(epochs, recall_values2, label='Propose2')
plt.plot(epochs, recall_values2, label='Propose')
plt.plot(epochs, test_recall, label='HCCF')
plt.title('Test Recall across Epochs (Yelp)')
plt.xlabel('Epochs')
plt.ylabel('Metrics Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Your data
epochs = [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99]
0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99]
recall_values = [0.0891, 0.1113, 0.1179, 0.1206, 0.1224, 0.1219, 0.1224, 0.1227, 0.1228, 0.1228, 0.1223, 0.1223, 0.1216, 0.1220, 0.1219, 0.1224, 0.1227, 0.1228, 0.1224, 0.1216, 0.1208, 0.1206, 0.1204, 0.1204, 0.1199, 0.1201, 0.1201, 0.1197, 0.1195, 0.1196, 0.1193, 0.1195, 0.1186, 0.1187]
ndcg_values = [0.0687, 0.0853, 0.0907, 0.0931, 0.0946, 0.0950, 0.0958, 0.0958, 0.0958, 0.0956, 0.0957, 0.0955, 0.0955, 0.0951, 0.0944, 0.0943, 0.0945, 0.0950, 0.0955, 0.0951, 0.0939, 0.0939, 0.0939, 0.0937, 0.0939, 0.0936, 0.0933, 0.0933, 0.0929, 0.0929, 0.0928, 0.0928, 0.0926, 0.0926]

# Your data
epochs2 = [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99]
test_recall = [0.0628, 0.0963, 0.1127, 0.1205, 0.1251, 0.1253, 0.1272, 0.1267, 0.1257, 0.1264, 
               0.1270, 0.1268, 0.1256, 0.1263, 0.1270, 0.1261, 0.1268, 0.1275, 0.1270, 0.1270,
               0.1270, 0.1270, 0.1270, 0.1270, 0.1273, 0.1289, 0.1263, 0.1270, 0.1280, 0.1273,
               0.1281, 0.1270]

test_ndcg = [0.0480, 0.0750, 0.0869, 0.0938, 0.0970, 0.0975, 0.0981, 0.0984, 0.0984, 0.0986,
             0.0986,  0.0985, 0.0985, 0.0982, 0.0983, 0.0984, 0.0984, 0.0982,
             0.0989, 0.0984, 0.0986,  0.0987, 0.0990, 0.0987, 0.0982, 0.0988,
             0.0992, 0.0986, 0.0987, 0.0987, 0.0987, 0.0987]

# Plotting
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))

# Plot Train Recall and NDCG
ax1.plot(epochs1, recall_values, label='Train Recall', color='blue')
ax1.plot(epochs1, test_recall, label='Train NDCG', color='orange')
ax1.set_title('Train Recall and NDCG over Epochs')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Value')
ax1.legend()
ax1.grid(True)

# Plot Test Recall and NDCG
ax2.plot(epochs2[:len(test_recall)], ndcg_values, label='Test Recall', color='blue')
ax2.plot(epochs2[:len(test_ndcg)], test_ndcg, label='Test NDCG', color='orange')
ax2.set_title('Test Recall and NDCG over Epochs')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Value')
ax2.legend()
ax2.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [21], line 25
#      23 # Plot Train Recall and NDCG
#      24 ax1.plot(epochs1, recall_values, label='Train Recall', color='blue')
# ---> 25 ax1.plot(epochs1, test_recall, label='Train NDCG', color='orange')
#      26 ax1.set_title('Train Recall and NDCG over Epochs')
#      27 ax1.set_xlabel('Epoch')
#
# File /home/user/anaconda3/envs/dose/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# ...

# %%
import re
import matplotlib.pyplot as plt

# Log data
log_data = """
2024-01-25 12:39:29.879001: Epoch 0/100, Test: Recall = 0.1072, NDCG = 0.0834
2024-01-25 12:40:14.628986: Epoch 3/100, Test: Recall = 0.1210, NDCG = 0.0933
2024-01-25 12:40:56.530904: Epoch 6/100, Test: Recall = 0.1194, NDCG = 0.0917
2024-01-25 12:41:38.555370: Epoch 9/100, Test: Recall = 0.1150, NDCG = 0.0884
2024-01-25 12:42:20.290183: Epoch 12/100, Test: Recall = 0.1129, NDCG = 0.0868
2024-01-25 12:43:02.427806: Epoch 15/100, Test: Recall = 0.1158, NDCG = 0.0887
2024-01-25 12:43:45.095654: Epoch 18/100, Test: Recall = 0.1192, NDCG = 0.0915
2024-01-25 12:44:26.992216: Epoch 21/100, Test: Recall = 0.1206, NDCG = 0.0929
2024-01-25 12:45:08.936191: Epoch 24/100, Test: Recall = 0.1225, NDCG = 0.0945
2024-01-25 12:45:51.200112: Epoch 27/100, Test: Recall = 0.1245, NDCG = 0.0962
2024-01-25 12:46:33.004551: Epoch 30/100, Test: Recall = 0.1260, NDCG = 0.0974
2024-01-25 12:47:15.254361: Epoch 33/100, Test: Recall = 0.1272, NDCG = 0.0982
2024-01-25 12:47:57.146363: Epoch 36/100, Test: Recall = 0.1286, NDCG = 0.0993
2024-01-25 12:48:38.942410: Epoch 39/100, Test: Recall = 0.1294, NDCG = 0.0998
2024-01-25 12:49:20.659441: Epoch 42/100, Test: Recall = 0.1296, NDCG = 0.1001
2024-01-25 12:50:02.406923: Epoch 45/100, Test: Recall = 0.1305, NDCG = 0.1008
2024-01-25 12:50:44.194652: Epoch 48/100, Test: Recall = 0.1307, NDCG = 0.1010
2024-01-25 12:51:26.031325: Epoch 51/100, Test: Recall = 0.1315, NDCG = 0.1013
2024-01-25 12:52:07.917908: Epoch 54/100, Test: Recall = 0.1316, NDCG = 0.1016
2024-01-25 12:52:49.751295: Epoch 57/100, Test: Recall = 0.1312, NDCG = 0.1012
2024-01-25 12:53:31.514192: Epoch 60/100, Test: Recall = 0.1317, NDCG = 0.1016
2024-01-25 12:54:13.229838: Epoch 63/100, Test: Recall = 0.1314, NDCG = 0.1016
2024-01-25 12:54:54.960814: Epoch 66/100, Test: Recall = 0.1316, NDCG = 0.1017
2024-01-25 12:55:36.610659: Epoch 69/100, Test: Recall = 0.1319, NDCG = 0.1017
2024-01-25 12:56:18.375927: Epoch 72/100, Test: Recall = 0.1318, NDCG = 0.1016
2024-01-25 12:57:00.103292: Epoch 75/100, Test: Recall = 0.1312, NDCG = 0.1014
2024-01-25 12:57:41.813557: Epoch 78/100, Test: Recall = 0.1314, NDCG = 0.1013
2024-01-25 12:58:23.617875: Epoch 81/100, Test: Recall = 0.1310, NDCG = 0.1013
2024-01-25 12:59:05.463519: Epoch 84/100, Test: Recall = 0.1312, NDCG = 0.1012
2024-01-25 12:59:47.225773: Epoch 87/100, Test: Recall = 0.1310, NDCG = 0.1011
2024-01-25 13:00:29.225472: Epoch 90/100, Test: Recall = 0.1313, NDCG = 0.1011
2024-01-25 13:01:10.861149: Epoch 93/100, Test: Recall = 0.1314, NDCG = 0.1011
2024-01-25 13:01:52.532998: Epoch 96/100, Test: Recall = 0.1310, NDCG = 0.1010
2024-01-25 13:02:34.171013: Epoch 99/100, Test: Recall = 0.1311, NDCG = 0.1010
"""

# Extract Recall and NDCG values
epochs = []
recall_values = []
ndcg_values = []

for line in log_data.split('\n'):
    match = re.search(r'Epoch (\d+)/\d+, Test: Recall = (\d+\.\d+), N
# Out:
#   Cell In [30], line 48
#     match = re.search(r'Epoch (\d+)/\d+, Test: Recall = (\d+\.\d+), N
#                                                                      ^
# SyntaxError: EOL while scanning string literal

# %%
import pandas as pd

# CSVファイルのパス
csv_path = '../Result/tem2024-01-29 17:31:58.csv'

# CSVファイルを読み込む
df = pd.read_csv(csv_path, delimiter=',')

# 'TestRecall'と'TestNDCG'列の右側の値を有効数字4桁で四捨五入
df['TestRecall'] = df['TestRecall'].apply(lambda x: round(x, 4))
df['TestNDCG'] = df['TestNDCG'].apply(lambda x: round(x, 4))

# 'TestRecall'と'TestNDCG'列をリストに変換
HCCF_amazon_test_recall_list = df['TestRecall'].tolist()
HCCF_amazon_test_ndcg_list = df['TestNDCG'].tolist()

# 結果の表示
print("TestRecall List:", HCCF_amazon_test_recall_list)
print("TestNDCG List:", HCCF_amazon_test_ndcg_list)
# Out:
# TestRecall List: [0.0432, 0.0932, 0.1058, 0.1126, 0.1152, 0.1175, 0.1187, 0.1192, 0.1203, 0.12, 0.1216, 0.1208, 0.1222, 0.1213, 0.1205, 0.122, 0.1225, 0.1218, 0.121, 0.1204, 0.1221, 0.1207, 0.1207, 0.1213, 0.1197, 0.1218, 0.1212, 0.1228, 0.1219, 0.1205, 0.1218, 0.1219, 0.1217, 0.1221, 0.1221]
# TestNDCG List: [0.0304, 0.0665, 0.0745, 0.0795, 0.0814, 0.0829, 0.0844, 0.0847, 0.0852, 0.0855, 0.0862, 0.0859, 0.086, 0.0862, 0.0856, 0.0865, 0.0864, 0.0861, 0.0857, 0.0848, 0.0866, 0.0856, 0.0859, 0.0861, 0.0852, 0.0861, 0.0858, 0.0869, 0.0866, 0.0853, 0.086, 0.0865, 0.0862, 0.0862, 0.0862]

# %%
import pandas as pd

# CSVファイルのパス
csv_path = '../Result/tem2024-01-29 17:43:40.csv'

# CSVファイルを読み込む
df = pd.read_csv(csv_path, delimiter=',')

# 'TestRecall'と'TestNDCG'列の右側の値を有効数字4桁で四捨五入
df['TestRecall'] = df['TestRecall'].apply(lambda x: round(x, 4))
df['TestNDCG'] = df['TestNDCG'].apply(lambda x: round(x, 4))

# 'TestRecall'と'TestNDCG'列をリストに変換
HCCF_ml_test_recall_list = df['TestRecall'].tolist()
HCCF_ml_test_ndcg_list = df['TestNDCG'].tolist()

# 結果の表示
print("TestRecall List:", HCCF_ml_test_recall_list)
print("TestNDCG List:", HCCF_ml_test_ndcg_list)
# Out:
# TestRecall List: [0.2401, 0.2737, 0.2716, 0.2722, 0.2725, 0.2722, 0.2685, 0.2655, 0.2642, 0.2659, 0.2666, 0.2658, 0.2649, 0.2622, 0.259, 0.2624, 0.2631, 0.2619, 0.2569, 0.258, 0.259, 0.2546, 0.2608, 0.2565, 0.2612, 0.2632, 0.2588, 0.2625, 0.2635, 0.2655, 0.2642, 0.2625, 0.2666, 0.2638, 0.2638]
# TestNDCG List: [0.2539, 0.291, 0.2897, 0.2906, 0.29, 0.2899, 0.2845, 0.2814, 0.2784, 0.2816, 0.2817, 0.28, 0.2799, 0.2769, 0.2729, 0.2783, 0.2788, 0.2774, 0.2717, 0.2743, 0.2774, 0.2711, 0.2807, 0.275, 0.281, 0.2838, 0.2783, 0.2851, 0.287, 0.2893, 0.2875, 0.2873, 0.2936, 0.289, 0.289]

# %%
epochs = [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 100]

# %%
import pandas as pd

# CSVファイルのパス
csv_path = '../Result/tem2024-01-29 18:29:11.csv'

# CSVファイルを読み込む
df = pd.read_csv(csv_path, delimiter=',')

# 'TestRecall'と'TestNDCG'列の右側の値を有効数字4桁で四捨五入
df['TestRecall'] = df['TestRecall'].apply(lambda x: round(x, 4))
df['TestNDCG'] = df['TestNDCG'].apply(lambda x: round(x, 4))

# 'TestRecall'と'TestNDCG'列をリストに変換
Propose_amazon_test_recall_list = df['TestRecall'].tolist()
Propose_amazon_test_ndcg_list = df['TestNDCG'].tolist()

# 結果の表示
print("TestRecall List:", Propose_amazon_test_recall_list)
print("TestNDCG List:", Propose_amazon_test_ndcg_list)
# Out:
# TestRecall List: [0.0889, 0.1169, 0.1213, 0.1223, 0.1229, 0.1212, 0.1204, 0.1195, 0.1182, 0.1183, 0.1199, 0.1201, 0.1222, 0.123, 0.124, 0.1247, 0.1253, 0.1263, 0.1268, 0.1274, 0.1273, 0.1282, 0.1278, 0.1282, 0.1285, 0.1286, 0.1281, 0.1286, 0.1282, 0.1281, 0.1286, 0.1273, 0.1279, 0.1277, 0.1277]
# TestNDCG List: [0.0626, 0.0826, 0.0855, 0.0855, 0.0852, 0.0842, 0.083, 0.0823, 0.0822, 0.0828, 0.0839, 0.0847, 0.0861, 0.0865, 0.0874, 0.0878, 0.0883, 0.0886, 0.089, 0.0893, 0.0895, 0.0897, 0.0899, 0.0899, 0.0901, 0.0901, 0.0899, 0.0901, 0.09, 0.0897, 0.0899, 0.0893, 0.0896, 0.0894, 0.0894]

# %%
import pandas as pd

# CSVファイルのパス
csv_path = '../Result/tem2024-01-29 18:59:01.csv'

# CSVファイルを読み込む
df = pd.read_csv(csv_path, delimiter=',')

# 'TestRecall'と'TestNDCG'列の右側の値を有効数字4桁で四捨五入
df['TestRecall'] = df['TestRecall'].apply(lambda x: round(x, 4))
df['TestNDCG'] = df['TestNDCG'].apply(lambda x: round(x, 4))

# 'TestRecall'と'TestNDCG'列をリストに変換
Propose_ml_test_recall_list = df['TestRecall'].tolist()
Propose_ml_test_ndcg_list = df['TestNDCG'].tolist()

# 結果の表示
print("TestRecall List:", Propose_ml_test_recall_list)
print("TestNDCG List:", Propose_ml_test_ndcg_list)
# Out:
# TestRecall List: [0.2552, 0.2751, 0.28, 0.2804, 0.2776, 0.277, 0.2815, 0.2874, 0.2949, 0.2994, 0.3024, 0.3042, 0.3048, 0.3069, 0.3081, 0.3101, 0.3104, 0.3102, 0.31, 0.3114, 0.3109, 0.3114, 0.312, 0.3121, 0.3118, 0.3123, 0.3115, 0.3119, 0.3117, 0.3119, 0.3114, 0.3119, 0.3128, 0.314, 0.314]
# TestNDCG List: [0.2664, 0.2906, 0.2956, 0.2969, 0.2959, 0.2968, 0.3054, 0.3142, 0.3244, 0.3306, 0.3345, 0.3364, 0.3376, 0.3397, 0.3415, 0.3433, 0.3439, 0.3436, 0.3432, 0.3444, 0.3439, 0.3446, 0.3459, 0.346, 0.3451, 0.3453, 0.3453, 0.3458, 0.3461, 0.3459, 0.3456, 0.3461, 0.3468, 0.3474, 0.3474]

# %%
import matplotlib.pyplot as plt


# Plotting
plt.figure(figsize=(10, 6))
# plt.plot(epochs, recall_values2, label='Propose2')
plt.plot(epochs, Propose_amazon_test_recall_list, label='Propose')
plt.plot(epochs, HCCF_amazon_test_recall_list, label='HCCF')
plt.title('Test Recall across Epochs (amazon)')
plt.xlabel('Epochs')
plt.ylabel('Metrics Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting
plt.figure(figsize=(10, 6))
# plt.plot(epochs, recall_values2, label='Propose2')
plt.plot(epochs, Propose_amazon_test_ndcg_list, label='Propose')
plt.plot(epochs, HCCF_amazon_test_ndcg_list, label='HCCF')
plt.title('Test NDCG across Epochs (amazon)')
plt.xlabel('Epochs')
plt.ylabel('Metrics Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting
plt.figure(figsize=(10, 6))
# plt.plot(epochs, recall_values2, label='Propose2')
plt.plot(epochs, Propose_ml_test_recall_list, label='Propose')
plt.plot(epochs, HCCF_ml_test_recall_list, label='HCCF')
plt.title('Test Recall across Epochs (Movie-lens)')
plt.xlabel('Epochs')
plt.ylabel('Metrics Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting
plt.figure(figsize=(10, 6))
# plt.plot(epochs, recall_values2, label='Propose2')
plt.plot(epochs, Propose_ml_test_ndcg_list, label='Propose')
plt.plot(epochs, HCCF_ml_test_ndcg_list, label='HCCF')
plt.title('Test NDCG across Epochs (Movie-lens)')
plt.xlabel('Epochs')
plt.ylabel('Metrics Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# サンプルデータ
epochs1 = range(100)
recall1 = [0.1 * i / 10 for i in epochs1]
recall2 = [0.08 * i / 10 for i in epochs1]
recall3 = [0.05 * i / 10 for i in epochs1]
recall4 = [0.07 * i / 10 for i in epochs1]
recall5 = [0.03 * i / 10 for i in epochs1]

epochs2 = range(50)  # 例として、異なる長さのepochを使用
recall6 = [0.1 * i / 10 for i in epochs2]

# グラフを描画
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# 左側のグラフ
ax[0].plot(epochs1, recall1, label='Ours')
ax[0].plot(epochs1, recall2, label='SGL')
ax[0].plot(epochs1, recall3, label='NCL')
ax[0].plot(epochs1, recall4, label='GCCF')
ax[0].plot(epochs1, recall5, label='STGCN')

ax[0].set_title('Yelp')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Recall@20')
ax[0].legend()

# 右側のグラフ
ax[1].plot(epochs2, recall6, label='Ours')
ax[1].plot(epochs1, recall2, label='SGL')
ax[1].plot(epochs1, recall3, label='NCL')
ax[1].plot(epochs1, recall4, label='GCCF')
ax[1].plot(epochs1, recall5, label='STGCN')

ax[1].set_title('Yelp')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Recall@20')
ax[1].legend()

plt.tight_layout()
plt.show()

# %%
# Epoch、TestRecall、TestNDCGのデー

DHCL_recall = [
    0.10820273806968823, 0.13906788423627142, 0.12808563601151512, 0.13692234713476922, 
    0.1466726343194656, 0.1540931353327635, 0.15978415100712853, 0.166665599401649, 
    0.16871711948747217, 0.1710147987095219, 0.17373342285438695, 0.1739473018611399, 
    0.17646863325371737, 0.1781436389637336, 0.17816337707560137, 0.1793621363852141, 
    0.09351158, 0.09330452, 0.09409666, 0.09374434, 0.09323798, 0.09442107, 
    0.09420091, 0.09418648, 0.09462712, 0.09524604, 0.09504558, 0.09546006, 
    0.09515283, 0.0956336, 0.0959605, 0.09603736, 0.09587908, 0.09492498, 
    0.09518762, 0.09511962, 0.09524552, 0.09496977, 0.09518602, 0.09476199, 
    0.09449513, 0.09498852, 0.0959605
]

SimGCL_recalls = [
    0.07965094, 0.11722679, 0.12745874, 0.13972718, 0.14957007, 0.15400331, 
    0.15663636, 0.16237439, 0.16376255, 0.16514315, 0.16444932, 0.16491186, 
    0.16724681, 0.1670647, 0.16874043, 0.16745074, 0.17023805, 0.17016678, 
    0.16725761, 0.16716207, 0.16781648, 0.16805311, 0.16620112, 0.16682525, 
    0.16751636, 0.16834476, 0.16856295, 0.16757315, 0.16693036, 0.16551647, 
    0.1673859, 0.16617594, 0.16419404, 0.16707111, 0.16540999, 0.16527459, 
    0.16729581, 0.16686705, 0.16589734, 0.16581558, 0.16672868, 0.16429976, 
    0.16408842, 0.16297901, 0.16217784, 0.16234323, 0.16212434, 0.16224499, 
    0.16468162, 0.16435592, 0.17023805
]

SimGCL_ndcgs = [
    0.04407503, 0.06392837, 0.06997218, 0.07706844, 0.08161584, 0.08413601, 
    0.08586282, 0.08787655, 0.08888363, 0.08951151, 0.08984874, 0.09091287, 
    0.09132528, 0.09117638, 0.09240885, 0.09256551, 0.09409329, 0.09413799, 
    0.09386199, 0.09424057, 0.09422557, 0.09451458, 0.09400601, 0.09433936, 
    0.09454706, 0.09459561, 0.09499248, 0.09415993, 0.09372449, 0.09367867, 
    0.09328631, 0.09312278, 0.09285339, 0.09380673, 0.09346184, 0.0931783, 
    0.09378538, 0.0934514, 0.09257213, 0.09261629, 0.09339093, 0.09240413, 
    0.09258419, 0.09189864, 0.09107526, 0.09115449, 0.09132037, 0.09144387, 
    0.0920591, 0.09184634, 0.09409329
]

# %%
import matplotlib.pyplot as plt

# サンプルデータ
epochs1 = range(51)
recall1 = DHCL_recall
recall2 = LightGCN_recalls
recall3 = SGL_recalls
recall4 = SimGCL_recalls
recall5 = HCCF_recall

ndcg1 = DHCL_ndcg
ndcg2 = LightGCN_ndcgs
ndcg3 = SGL_ndcgs
ndcg4 = SimGCL_ndcgs
ndcg5 = HCCF_ndcg

# グラフを描画
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# 左側のグラフ
ax[0].plot(epochs1, recall1, label='DHCL')
ax[0].plot(epochs1, recall2, label='LightGCN')
ax[0].plot(epochs1, recall3, label='SGL')
ax[0].plot(epochs1, recall4, label='SimGCL')
ax[0].plot(epochs1, recall5, label='HCCF')

ax[0].set_title('Yelp')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Recall@20')
ax[0].legend()

# 右側のグラフ
ax[1].plot(epochs1, ndcg1, label='DHCL')
ax[1].plot(epochs1, ndcg2, label='LightGCN')
ax[1].plot(epochs1, ndcg3, label='SGL')
ax[1].plot(epochs1, ndcg4, label='SimGCL')
ax[1].plot(epochs1, ndcg5, label='HCCF')

ax[1].set_title('Yelp')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('NDCG@20')
ax[1].legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
methods = ['w/o IG', 'w/o HG', 'w/o HSL','DHCL']
amazon_books = [0.1367, 0.2152, 0.2325, 0.2377]
gowalla = [0.0952, 0.1556, 0.1685,  0.1707]

x = np.arange(len(methods))  # the label locations
width = 0.45  # the width of the bars

fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Amazon-books plot
rects1 = ax[0].bar(x - width/2, amazon_books, width, label='Amazon-books', color=['#FFA07A', '#98FB98', '#FF6347', '#4682B4'])
ax[0].set_ylabel('Recall@20')
# ax[0].set_title('Amazon-books')
ax[0].set_xticks(x)
ax[0].set_xticklabels(methods)
ax[0].set_ylim(0, 0.3)  # Adjusted to add some padding above the highest bar

# Gowalla plot
rects2 = ax[1].bar(x - width/2, gowalla, width, label='Gowalla', color=['#FFA07A', '#98FB98', '#FF6347', '#4682B4'])
ax[1].set_ylabel('NDCG@20')
# ax[1].set_title('Gowalla')
ax[1].set_xticks(x)
ax[1].set_xticklabels(methods)
ax[1].set_ylim(0, 0.2)  # Adjusted to add some padding above the highest bar

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ
methods = ['w/o HG', 'w/o HSL','DHCL']
amazon_books = [0.2152, 0.2325, 0.2377]
gowalla = [0.1556, 0.1685,  0.1707]

x = np.arange(len(methods))  # ラベルの位置
width = 0.35  # 棒の幅

fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Amazon-books プロット
rects1 = ax[0].bar(x - width/2, amazon_books, width, label='Amazon-books', color=['lightseagreen', 'lightskyblue', 'dodgerblue'])
ax[0].set_ylabel('Recall@20')
ax[0].set_xticks(x)
ax[0].set_xticklabels(methods)
ax[0].set_ylim(0.2, 0.25)  # 最高の棒の上に少し余白を追加

# Gowalla プロット
rects2 = ax[1].bar(x - width/2, gowalla, width, label='Gowalla', color=['lightseagreen', 'lightskyblue', 'dodgerblue'])
ax[1].set_ylabel('Recall@20')
ax[1].set_xticks(x)
ax[1].set_xticklabels(methods)
ax[1].set_ylim(0.15, 0.18)  # 最高の棒の上に少し余白を追加

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ
methods = ['w/o HG', 'w/o HSL','DHCL']
amazon_books = [0.2152, 0.2325, 0.2377]
gowalla = [0.1556, 0.1685,  0.1707]

x = np.arange(len(methods))  # ラベルの位置
width = 0.55  # 棒の幅

fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Amazon-books プロット
rects1 = ax[0].bar(x, amazon_books, width, label='Amazon-books', align="center", color=['powderblue', 'lightskyblue', 'dodgerblue'])
ax[0].set_ylabel('Recall@20')
ax[0].set_xticks(x)
ax[0].set_xticklabels(methods)
ax[0].set_ylim(0.2, 0.25)  # 最高の棒の上に少し余白を追加

# Gowalla プロット
# rects2 = ax[1].bar(x, gowalla, width, label='Gowalla', color=['powderblue', 'lightskyblue', 'dodgerblue'])
# ax[1].set_ylabel('Recall@20')
# ax[1].set_xticks(x)
# ax[1].set_xticklabels(methods)
# ax[1].set_ylim(0.15, 0.18)  # 最高の棒の上に少し余白を追加

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ
methods = ['w/o HG', 'w/o HSL','DHCL']
amazon_books = [0.2152, 0.2325, 0.2377]
gowalla = [0.1556, 0.1685,  0.1707]

x = np.arange(len(methods))  # ラベルの位置
width = 0.55  # 棒の幅

fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Amazon-books プロット
rects1 = ax[0].bar(x, amazon_books, width, label='Amazon-books', align="center", color=['powderblue', 'lightskyblue', 'dodgerblue'])
ax[0].set_ylabel('Recall@20',fontsize=28)
ax[0].set_xticks(x)
ax[0].set_xticklabels(methods, fontsize=24)
ax[0].set_ylim(0.2, 0.25)  # 最高の棒の上に少し余白を追加
ax[0].tick_params(axis='y', labelsize=24) 

# Gowalla プロット
# rects2 = ax[1].bar(x, gowalla, width, label='Gowalla', color=['powderblue', 'lightskyblue', 'dodgerblue'])
# ax[1].set_ylabel('Recall@20')
# ax[1].set_xticks(x)
# ax[1].set_xticklabels(methods)
# ax[1].set_ylim(0.15, 0.18)  # 最高の棒の上に少し余白を追加

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ
methods = ['w/o HG', 'w/o HSL','DHCL']
amazon_books = [0.2152, 0.2325, 0.2377]
gowalla = [0.1556, 0.1685,  0.1707]

x = np.arange(len(methods))  # ラベルの位置
width = 0.55  # 棒の幅

fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Amazon-books プロット
rects1 = ax[0].bar(x, gowalla, width, label='Amazon-books', align="center", color=['powderblue', 'lightskyblue', 'dodgerblue'])
ax[0].set_ylabel('NDCG@20', fontsize=28)
ax[0].set_xticks(x)
ax[0].set_xticklabels(methods, fontsize=24)
ax[0].set_ylim(0.15, 0.18)  # 最高の棒の上に少し余白を追加
ax[0].tick_params(axis='y', labelsize=24) 
# Gowalla プロット
# rects2 = ax[1].bar(x, gowalla, width, label='Gowalla', align="center", color=['powderblue', 'lightskyblue', 'dodgerblue'])
# ax[1].set_ylabel('NDCG@20', fontsize=14)
# ax[1].set_xticks(x)
# ax[1].set_xticklabels(methods, fontsize=14)
# ax[1].set_ylim(0.15, 0.18)  # 最高の棒の上に少し余白を追加

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ
methods = ['w/o HG', 'w/o HSL','DHCL']
amazon_books = [0.1681, 0.1858, 0.1860]
gowalla = [0.1112, 0.1229,  0.1242]

x = np.arange(len(methods))  # ラベルの位置
width = 0.55  # 棒の幅

fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Amazon-books プロット
rects1 = ax[0].bar(x, amazon_books, width, label='Amazon-books', align="center", color=['powderblue', 'lightskyblue', 'dodgerblue'])
ax[0].set_ylabel('Recall@20',fontsize=28)
ax[0].set_xticks(x)
ax[0].set_xticklabels(methods, fontsize=24)
ax[0].set_ylim(0.16, 0.2)  # 最高の棒の上に少し余白を追加
ax[0].tick_params(axis='y', labelsize=24) 

# Gowalla プロット
# rects2 = ax[1].bar(x, gowalla, width, label='Gowalla', color=['powderblue', 'lightskyblue', 'dodgerblue'])
# ax[1].set_ylabel('Recall@20')
# ax[1].set_xticks(x)
# ax[1].set_xticklabels(methods)
# ax[1].set_ylim(0.15, 0.18)  # 最高の棒の上に少し余白を追加

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ
methods = ['w/o HG', 'w/o HSL','DHCL']
amazon_books = [0.1681, 0.1858, 0.1860]
gowalla = [0.1112, 0.1229,  0.1242]

x = np.arange(len(methods))  # ラベルの位置
width = 0.55  # 棒の幅

fig, ax = plt.subplots(1, 2, figsize=(12, 8), sharey=True)

# Amazon-books プロット
rects1 = ax[0].bar(x, gowalla, width, label='Amazon-books', align="center", color=['powderblue', 'lightskyblue', 'dodgerblue'])
ax[0].set_ylabel('NDCG@20', fontsize=18)
ax[0].set_xticks(x)
ax[0].set_xticklabels(methods, fontsize=18)
ax[0].set_ylim(0.1, 0.13)  # 最高の棒の上に少し余白を追加
ax[0].tick_params(axis='y', labelsize=14) 
# Gowalla プロット
# rects2 = ax[1].bar(x, gowalla, width, label='Gowalla', align="center", color=['powderblue', 'lightskyblue', 'dodgerblue'])
# ax[1].set_ylabel('NDCG@20', fontsize=14)
# ax[1].set_xticks(x)
# ax[1].set_xticklabels(methods, fontsize=14)
# ax[1].set_ylim(0.15, 0.18)  # 最高の棒の上に少し余白を追加

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ
gnn_layers = [1, 2, 3]
DHCL_k_recall = [0.1813, 0.1842, 0.1862]
DHCL_k_ndcg = [0.1199, 0.1214, 0.1222]
lightgcn_k_recall = [0.1681, 0.1686, 0.1634]
lightgcn_k_ndcg = [0.1106, 0.1109, 0.1064]
lightgcl_k_recall = [0.1730, 0.1719, 0.1303]
lightgcl_k_ndcg = [0.1143, 0.1154, 0.0843]

# グラフの描画
fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Recallプロット
ax[0].plot(gnn_layers, DHCL_k_recall, 'bs-', label='DHCL')
ax[0].plot(gnn_layers, lightgcn_k_recall, 'ro-', label='LightGCN')
ax[0].plot(gnn_layers, lightgcl_k_recall, 'g^-', label='LightGCL')
ax[0].set_xlabel('Number of GNN layers')
ax[0].set_ylabel('Recall@20')
ax[0].set_xticks(gnn_layers)
ax[0].legend()

# NDCGプロット
ax[1].plot(gnn_layers, DHCL_k_ndcg, 'bs-', label='DHCL')
ax[1].plot(gnn_layers, lightgcn_k_ndcg, 'ro-', label='LightGCN')
ax[1].plot(gnn_layers, lightgcl_k_ndcg, 'g^-', label='LightGCL')
ax[1].set_xlabel('Number of GNN layers')
ax[1].set_ylabel('NDCG@20')
ax[1].set_xticks(gnn_layers)
ax[1].legend()

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ
gnn_layers = [1, 2, 3]
DHCL_k_recall = [0.1813, 0.1842, 0.1862]
DHCL_k_ndcg = [0.1199, 0.1214, 0.1222]
lightgcn_k_recall = [0.1681, 0.1686, 0.1634]
lightgcn_k_ndcg = [0.1106, 0.1109, 0.1064]
lightgcl_k_recall = [0.1730, 0.1719, 0.1303]
lightgcl_k_ndcg = [0.1143, 0.1154, 0.0843]

# グラフの描画
fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Recallプロット
# ax[0].plot(gnn_layers, DHCL_k_recall, 'bs-', label='DHCL')
# ax[0].plot(gnn_layers, lightgcn_k_recall, 'ro-', label='LightGCN')
# ax[0].plot(gnn_layers, lightgcl_k_recall, 'g^-', label='LightGCL')
# ax[0].set_xlabel('Number of GNN layers')
# ax[0].set_ylabel('Recall@20')
# ax[0].set_xticks(gnn_layers)
# ax[0].legend()

# NDCGプロット
ax[0].plot(gnn_layers, DHCL_k_ndcg, 'bs-', label='DHCL')
ax[0].plot(gnn_layers, lightgcn_k_ndcg, 'ro-', label='LightGCN')
ax[0].plot(gnn_layers, lightgcl_k_ndcg, 'g^-', label='LightGCL')
ax[0].set_xlabel('Number of GNN layers')
ax[0].set_ylabel('NDCG@20')
ax[0].set_xticks(gnn_layers)
ax[0].legend()

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ
gnn_layers = [1, 2, 3]
DHCL_k_recall = [0.1813, 0.1842, 0.1862]
DHCL_k_ndcg = [0.1199, 0.1214, 0.1222]
lightgcn_k_recall = [0.1681, 0.1686, 0.1634]
lightgcn_k_ndcg = [0.1106, 0.1109, 0.1064]
lightgcl_k_recall = [0.1730, 0.1719, 0.1303]
lightgcl_k_ndcg = [0.1143, 0.1154, 0.0843]

# グラフの描画
fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Recallプロット
ax[0].plot(gnn_layers, DHCL_k_recall, 'o-', color='coral', label='HGCL', markersize=14)
ax[0].plot(gnn_layers, lightgcn_k_recall, 's-', color='steelblue', label='LightGCN', markersize=14)
ax[0].plot(gnn_layers, lightgcl_k_recall, '^-', color='deepskyblue', label='LightGCL', markersize=14)
ax[0].set_xlabel('k-hop neighbors to convolute', fontsize=24)
ax[0].set_ylabel('Recall@20', fontsize=28)
ax[0].set_xticks(gnn_layers)
ax[0].tick_params(axis='y', labelsize=24) 
ax[0].tick_params(axis='x', labelsize=24) 
ax[0].legend(fontsize=24)

# NDCGプロット
ax[1].plot(gnn_layers, DHCL_k_ndcg, 'o-', color='coral', label='DHCL')
ax[1].plot(gnn_layers, lightgcn_k_ndcg, 's-', color='steelblue', label='LightGCN')
ax[1].plot(gnn_layers, lightgcl_k_ndcg, '^-', color='deepskyblue', label='LightGCL')
ax[1].set_xlabel('Number of GNN layers')
ax[1].set_ylabel('NDCG@20')
ax[1].set_xticks(gnn_layers)
ax[1].legend()

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ
gnn_layers = [1, 2, 3]
DHCL_k_recall = [0.1813, 0.1842, 0.1862]
DHCL_k_ndcg = [0.1199, 0.1214, 0.1222]
lightgcn_k_recall = [0.1681, 0.1686, 0.1634]
lightgcn_k_ndcg = [0.1106, 0.1109, 0.1064]
lightgcl_k_recall = [0.1730, 0.1719, 0.1303]
lightgcl_k_ndcg = [0.1143, 0.1154, 0.0843]

# グラフの描画
fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Recallプロット
ax[0].plot(gnn_layers, DHCL_k_ndcg, 'o-', color='coral', label='HGCL',  markersize=14)
ax[0].plot(gnn_layers, lightgcn_k_ndcg, 's-', color='steelblue', label='LightGCN', markersize=14)
ax[0].plot(gnn_layers, lightgcl_k_ndcg, '^-', color='deepskyblue', label='LightGCL', markersize=14)
ax[0].set_xlabel('k-hop neighbors to convolute', fontsize=24)
ax[0].set_ylabel('NDCG@20', fontsize=28)
ax[0].tick_params(axis='y', labelsize=24) 
ax[0].tick_params(axis='x', labelsize=24) 
ax[0].set_xticks(gnn_layers)
# ax[0].legend(fontsize=24)

# NDCGプロット
ax[1].plot(gnn_layers, DHCL_k_ndcg, 'o-', color='coral', label='DHCL')
ax[1].plot(gnn_layers, lightgcn_k_ndcg, 's-', color='steelblue', label='LightGCN')
ax[1].plot(gnn_layers, lightgcl_k_ndcg, '^-', color='deepskyblue', label='LightGCL')
ax[1].set_xlabel('Number of GNN layers')
ax[1].set_ylabel('NDCG@20')
ax[1].set_xticks(gnn_layers)
ax[1].legend()

fig.tight_layout()
plt.show()
